# %%
# Imporing Important Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("liver_patient.csv")

# %%
data
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male              0.5               0.1                   500
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 582   38    Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %% [markdown]
# # **Basic Checks**

# %%
data.shape
# Out:
# (583, 11)

# %%
data.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Outcome
# 0      3.3                        0.90        1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Outcome                     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
data.describe().T
# Out:
#                             count        mean         std   min    25%  \
# Age                         583.0   44.746141   16.189833   4.0   33.0
# Total_Bilirubin             583.0    3.298799    6.209522   0.4    0.8
# Direct_Bilirubin            583.0    1.486106    2.808498   0.1    0.2
# Alkaline_Phosphotase        583.0  290.576329  242.937989  63.0  175.5
# Alamine_Aminotransferase    583.0   80.713551  182.620356  10.0   23.0
# Aspartate_Aminotransferase  583.0  109.910806  288.918529  10.0   25.0
# Total_Protiens              583.0    6.483190    1.085451   2.7    5.8
# Albumin                     583.0    3.141852    0.795519   0.9    2.6
# Albumin_and_Globulin_Ratio  579.0    0.947064    0.319592   0.3    0.7
# Outcome                     583.0    1.286449    0.452490   1.0    1.0
#
#                                50%    75%     max
# Age                          45.00   58.0    90.0
# Total_Bilirubin               1.00    2.6    75.0
# ...

# %% [markdown]
# ### **Insights**

# %% [markdown]
# * Age: Most people are around 45 years old, but there's a wide age range from 4 to 90 years.
#
# * Bilirubin Levels: Some individuals have very high bilirubin levels, especially Total Bilirubin and Direct Bilirubin.
#
# * Liver Enzymes: Alkaline Phosphatase, Alamine Aminotransferase, and Aspartate Aminotransferase levels vary a lot, with some very high values.
#
# * Protein Levels: Total Proteins and Albumin levels are relatively stable across the dataset.
#
# * Outcome: There are two possible outcomes (1 and 2), with most cases falling into category 1.

# %%
# checking numerical columns and storing
num_data = data.select_dtypes(include=["float64","int64"])
num_data.columns
# Out:
# Index(['Age', 'Total_Bilirubin', 'Direct_Bilirubin', 'Alkaline_Phosphotase',
#        'Alamine_Aminotransferase', 'Aspartate_Aminotransferase',
#        'Total_Protiens', 'Albumin', 'Albumin_and_Globulin_Ratio', 'Outcome'],
#       dtype='object')

# %%
num_data
# Out:
#      Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65              0.7               0.1                   187
# 1     62             10.9               5.5                   699
# 2     62              7.3               4.1                   490
# 3     58              1.0               0.4                   182
# 4     72              3.9               2.0                   195
# ..   ...              ...               ...                   ...
# 578   60              0.5               0.1                   500
# 579   40              0.6               0.1                    98
# 580   52              0.8               0.2                   245
# 581   31              1.3               0.5                   184
# 582   38              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          16                          18             6.8
# ...

# %%
# there is only one categorical column and storing
cat_data = data[["Gender"]]

# %%
cat_data
# Out:
#      Gender
# 0    Female
# 1      Male
# 2      Male
# 3      Male
# 4      Male
# ..      ...
# 578    Male
# 579    Male
# 580    Male
# 581    Male
# 582    Male
#
# [583 rows x 1 columns]

# %%
#outcome
# 1 represents Patient with Liver Disease
# 2 represents Patient with no liver Disease
data.Outcome.unique()
# Out:
# array([1, 2])

# %%
data.Outcome.value_counts()
# Out:
# 1    416
# 2    167
# Name: Outcome, dtype: int64

# %% [markdown]
# # **EDA - Exploratory data analysis**

# %% [markdown]
# ## **Univariant Analysis**

# %%
 # !pip install sweetviz

# %%
 import sweetviz as sv
 my_report = sv.analyze(data)
 my_report.show_html(filepath="/content/SWEETVIZ_REPORT.html")

# %% [markdown]
# ### **Insights**

# %% [markdown]
# * **Age:** Most patients fall within the age range of 26 to 60, with the highest concentration at 60 (5.8%). The youngest patient is 4, and the oldest is 90.
#
# * **Gender:** Over 70% of the patients are male, while the remaining are female.
#
# * **Total_Bilirubin:** More than 80% of values fall between 0.0 and 10.0, with 95% of values below 16.3.
#
# * **Direct_Bilirubin:** Over 80% of values are between 0.0 and 2.5, showing a high correlation (0.87) with total bilirubin.
#
# * **Alkaline_Phosphotase:** Approximately 60% of values range from 145 to 298, with 95% below 698. The highest value is 2110, while the lowest is 63.
#
# * **Alamine_Aminotransferase:** 95% of values are between 0 and 232, with a maximum value of 2000.
#
# * **Aspartate_Aminotransferase:** 95% of values fall between 15 and 401, with a maximum value of 4929.
#
# * **Total_Proteins:** Highly correlated (0.78) with albumin, this feature ranges from a minimum of 2.70 to a maximum of 9.60, with most values between 5.0 and 7.0.
#
# * **Albumin:** Ranging from 0.90 to 5.50, most values are between 2.0 and 5.0.
#
# * **Albumin_and_Globulin_Ratio:** This feature spans from 0.30 to 2.80, with more than 40% of values near 1.0.
#
# * **Outcome:** Out of the patients, 71% (416 individuals) do not have liver disease, while 29% (167 individuals) have been diagnosed with liver disease.

# %% [markdown]
# ## **Bivariate Analysis**

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Outcome'],
#       dtype='object')

# %%
plt.figure(figsize=(17, 50))
plotnumber = 1



for column in num_data.drop(['Outcome'],axis=1):
    if plotnumber <= 10:
        ax = plt.subplot(10, 1, plotnumber)
        sns.histplot(x=num_data[column], hue=data['Outcome'], palette=["green","red"])
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Outcome',fontsize=20)
        plt.xticks(rotation=40)

    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
sns.histplot(x=data['Gender'], hue=data['Outcome'])
# Out:
# <Axes: xlabel='Gender', ylabel='Count'>

# %% [markdown]
# ### **Insights**

# %% [markdown]
# * **Age:** The incidence of liver disease tends to increase with age, with even a few cases below the age of 20.
#
# * **Total_Bilirubin:** Liver disease occurs across a range of total bilirubin levels, from low to high.
#
# * **Direct_Bilirubin:** Liver disease is more prevalent when direct bilirubin levels are close to 0.0.
#
# * **Alkaline_Phosphatase**: Liver disease is more common when alkaline phosphatase levels are between 0 and 500.
#
# * **Alamine_Aminotransferase and Aspartate_Aminotransferase:** Both enzymes exhibit a similar pattern, with more liver disease cases when their levels are near 0 and decreasing as levels increase.
#
# * **Total_Proteins:** Liver disease can occur at both low and high levels of total proteins.
#
# * **Albumin and Albumin_and_Globulin_Ratio:** Higher levels of albumin and albumin-to-globulin ratio are associated with an increased likelihood of liver disease.
#
# * **Gender:** The prevalence of liver disease is higher among male patients compared to female patients.

# %% [markdown]
# ## **Multivariate Analysis**

# %%
 sns.pairplot(data,hue='Outcome')

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# ## **Handling Missing Values**

# %%
# checking for null values
data.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Outcome                       0
# dtype: int64

# %%
sns.histplot(data["Albumin_and_Globulin_Ratio"],kde=True)
# Out:
# <Axes: xlabel='Albumin_and_Globulin_Ratio', ylabel='Count'>

# %%
data.loc[data['Albumin_and_Globulin_Ratio'].isnull()==True,'Albumin_and_Globulin_Ratio']=data['Albumin_and_Globulin_Ratio'].median()

# %%
data.Albumin_and_Globulin_Ratio.isnull().sum()
# Out:
# 0

# %%
# there was only one column with missing values and we fixed that with median

# %% [markdown]
# ## **Checking for outliers**

# %%
num_data
# Out:
#      Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65              0.7               0.1                   187
# 1     62             10.9               5.5                   699
# 2     62              7.3               4.1                   490
# 3     58              1.0               0.4                   182
# 4     72              3.9               2.0                   195
# ..   ...              ...               ...                   ...
# 578   60              0.5               0.1                   500
# 579   40              0.6               0.1                    98
# 580   52              0.8               0.2                   245
# 581   31              1.3               0.5                   184
# 582   38              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          16                          18             6.8
# ...

# %%
num_data.shape
# Out:
# (583, 10)

# %%
plt.figure(figsize=(10,30),facecolor='white')
plotnumber=1

for column in num_data.drop('Outcome',axis=1):
  if plotnumber<=10:
    ax=plt.subplot(10,1,plotnumber)
    sns.boxplot(x=data[column])
    plt.xlabel(column,fontsize=10)
    plt.ylabel('Count',fontsize=10)
  plotnumber+=1
plt.tight_layout()

# %%
num_data.columns
# Out:
# Index(['Age', 'Total_Bilirubin', 'Direct_Bilirubin', 'Alkaline_Phosphotase',
#        'Alamine_Aminotransferase', 'Aspartate_Aminotransferase',
#        'Total_Protiens', 'Albumin', 'Albumin_and_Globulin_Ratio', 'Outcome'],
#       dtype='object')

# %%
# List of column names to analyze
columns_to_analyze = ['Total_Bilirubin', 'Direct_Bilirubin', 'Alkaline_Phosphotase',
                      'Alamine_Aminotransferase', 'Aspartate_Aminotransferase',
                      'Total_Protiens', 'Albumin_and_Globulin_Ratio']

for column in columns_to_analyze:
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR


    lower_outliers = len(data.loc[data[column] < lower_limit])
    upper_outliers = len(data.loc[data[column] > upper_limit])
    total_outliers = lower_outliers + upper_outliers
    total_records = len(data)

    print(f"Column: {column}")
    print(f"IQR: {IQR}")
    print(f"Lower Limit: {lower_limit}")
    print(f"Upper Limit: {upper_limit}")
    print(f"Percentage of Lower Outliers: {(lower_outliers / total_records) * 100}%")
    print(f"Percentage of Upper Outliers: {(upper_outliers / total_records) * 100}%")
    print(f"Total Outliers: {total_outliers}\n")
# Out:
# Column: Total_Bilirubin
# IQR: 1.8
# Lower Limit: -1.9000000000000001
# Upper Limit: 5.300000000000001
# Percentage of Lower Outliers: 0.0%
# Percentage of Upper Outliers: 14.408233276157805%
# Total Outliers: 84
#
# Column: Direct_Bilirubin
# IQR: 1.1
# Lower Limit: -1.4500000000000002
# Upper Limit: 2.95
# Percentage of Lower Outliers: 0.0%
# Percentage of Upper Outliers: 13.893653516295027%
# Total Outliers: 81
#
# Column: Alkaline_Phosphotase
# IQR: 122.5
# Lower Limit: -8.25
# Upper Limit: 481.75
# Percentage of Lower Outliers: 0.0%
# Percentage of Upper Outliers: 11.83533447684391%
# Total Outliers: 69
#
# Column: Alamine_Aminotransferase
# IQR: 37.5
# Lower Limit: -33.25
# Upper Limit: 116.75
# Percentage of Lower Outliers: 0.0%
# Percentage of Upper Outliers: 12.521440823327614%
# Total Outliers: 73
#
# Column: Aspartate_Aminotransferase
# IQR: 62.0
# Lower Limit: -68.0
# Upper Limit: 180.0
# Percentage of Lower Outliers: 0.0%
# ...

# %%
# since all the outliers are above 5% so it holds some data, and these columns [Total_Protiens , Albumin_and_Globulin_Ratio]
# have very less amount of outliers so it was not necessary to handle them

# %% [markdown]
# ## **Scaling**

# %%
data.head(5)
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Outcome
# 0      3.3                        0.90        1
# ...

# %%
num_data.columns
# Out:
# Index(['Age', 'Total_Bilirubin', 'Direct_Bilirubin', 'Alkaline_Phosphotase',
#        'Alamine_Aminotransferase', 'Aspartate_Aminotransferase',
#        'Total_Protiens', 'Albumin', 'Albumin_and_Globulin_Ratio', 'Outcome'],
#       dtype='object')

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
data[['Age', 'Total_Bilirubin', 'Direct_Bilirubin', 'Alkaline_Phosphotase','Alamine_Aminotransferase',
    'Aspartate_Aminotransferase','Total_Protiens', 'Albumin', 'Albumin_and_Globulin_Ratio']]=scaler.fit_transform(data[['Age', 'Total_Bilirubin','Direct_Bilirubin', 'Alkaline_Phosphotase',
    'Alamine_Aminotransferase', 'Aspartate_Aminotransferase','Total_Protiens', 'Albumin', 'Albumin_and_Globulin_Ratio']])

data
# Out:
#       Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0    0.80  Female        -0.166667         -0.181818             -0.171429
# 1    0.68    Male         5.500000          4.727273              4.008163
# 2    0.68    Male         3.500000          3.454545              2.302041
# 3    0.52    Male         0.000000          0.090909             -0.212245
# 4    1.08    Male         1.611111          1.545455             -0.106122
# ..    ...     ...              ...               ...                   ...
# 578  0.60    Male        -0.277778         -0.181818              2.383673
# 579 -0.20    Male        -0.222222         -0.181818             -0.897959
# 580  0.28    Male        -0.111111         -0.090909              0.302041
# 581 -0.56    Male         0.166667          0.181818             -0.195918
# 582 -0.28    Male         0.000000          0.000000              0.065306
#
# ...

# %% [markdown]
# ## **Converting Categorical into Numerical**

# %%
from sklearn.preprocessing import LabelEncoder

lc=LabelEncoder()

data.Gender=lc.fit_transform(data.Gender)

data
# female 0
# male 1
# since there was only one column categorical which is gender column so we fixed that using labelencoder
# Out:
#       Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0    0.80       0        -0.166667         -0.181818             -0.171429
# 1    0.68       1         5.500000          4.727273              4.008163
# 2    0.68       1         3.500000          3.454545              2.302041
# 3    0.52       1         0.000000          0.090909             -0.212245
# 4    1.08       1         1.611111          1.545455             -0.106122
# ..    ...     ...              ...               ...                   ...
# 578  0.60       1        -0.277778         -0.181818              2.383673
# 579 -0.20       1        -0.222222         -0.181818             -0.897959
# 580  0.28       1        -0.111111         -0.090909              0.302041
# 581 -0.56       1         0.166667          0.181818             -0.195918
# 582 -0.28       1         0.000000          0.000000              0.065306
#
# ...

# %% [markdown]
# # **Feature Selection**

# %%
plt.figure(figsize=(9,10))
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
#least corelations columns with target
correlations = data.corr()['Outcome']
least_correlated_columns = correlations[(correlations >= -0.1) & (correlations <= 0.2)]


print(least_correlated_columns)
# Out:
# Gender                       -0.082416
# Total_Protiens                0.035008
# Albumin                       0.161388
# Albumin_and_Globulin_Ratio    0.162144
# Name: Outcome, dtype: float64

# %%
correlation_matrix = data.corr()

print("Highly Correlated Column Pairs (Correlation > 0.80):")
for col1 in correlation_matrix.columns:
    for col2 in correlation_matrix.columns:
        if col1 != col2 and correlation_matrix[col1][col2] > 0.75:
            print(f"{col1} and {col2}: {correlation_matrix[col1][col2]}")
# Out:
# Highly Correlated Column Pairs (Correlation > 0.80):
# Total_Bilirubin and Direct_Bilirubin: 0.874617930116413
# Direct_Bilirubin and Total_Bilirubin: 0.874617930116413
# Alamine_Aminotransferase and Aspartate_Aminotransferase: 0.791965684853615
# Aspartate_Aminotransferase and Alamine_Aminotransferase: 0.791965684853615
# Total_Protiens and Albumin: 0.784053335387192
# Albumin and Total_Protiens: 0.784053335387192

# %%
data.drop(['Total_Bilirubin'], axis=1,inplace=True)

# %%
data.shape
# Out:
# (583, 10)

# %%
# these two colums is highly correlated Total_Bilirubin and Direct_Bilirubin above 0.8
# so I removed one of the column which is Total_Bilirubin

# %% [markdown]
# # **Model Building**

# %%
# splitting data for training and testing
x=data.drop(['Outcome'],axis=1)
y=data[['Outcome']]

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=15)

# %%
x_train.shape
# Out:
# (466, 9)

# %%
x_test.shape
# Out:
# (117, 9)

# %% [markdown]
# ## **Support Vector Classifier**

# %%
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

svc_model = SVC()
svc_model.fit(x_train, y_train)

svc_pred = svc_model.predict(x_test)

conf_matrix = confusion_matrix(y_test, svc_pred)
print("Confusion Matrix:")
print(conf_matrix)

accuracy = accuracy_score(y_test, svc_pred)
print("Accuracy:", accuracy)

precision = precision_score(y_test, svc_pred)
print("Precision:", precision)

recall = recall_score(y_test, svc_pred)
print("Recall:", recall)

f1 = f1_score(y_test, svc_pred)
print("F1 Score:", f1)
# Out:
# Confusion Matrix:
# [[88  0]
#  [29  0]]
# Accuracy: 0.7521367521367521
# Precision: 0.7521367521367521
# Recall: 1.0
# F1 Score: 85.85365853658537

# %% [markdown]
# ## **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

logistic_regression_model = LogisticRegression()
logistic_regression_model.fit(x_train, y_train)

logistic_regression_pred = logistic_regression_model.predict(x_test)

conf_matrix = confusion_matrix(y_test, logistic_regression_pred)
print("Confusion Matrix:")
print(conf_matrix)

accuracy = accuracy_score(y_test, logistic_regression_pred)
print("Accuracy:", accuracy)

precision = precision_score(y_test, logistic_regression_pred)
print("Precision:", precision)

recall = recall_score(y_test, logistic_regression_pred)
print("Recall:", recall)

f1 = f1_score(y_test, logistic_regression_pred)
print("F1 Score:", f1)
# Out:
# Confusion Matrix:
# [[80  8]
#  [20  9]]
# Accuracy: 0.7606837606837606
# Precision: 0.8
# Recall: 0.9090909090909091
# F1 Score: 85.10638297872342

# %% [markdown]
# ## **Random Forest Classifier**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

random_forest_model = RandomForestClassifier()
random_forest_model.fit(x_train, y_train)

random_forest_pred = random_forest_model.predict(x_test)

conf_matrix = confusion_matrix(y_test, random_forest_pred)
print("Confusion Matrix:")
print(conf_matrix)

accuracy = accuracy_score(y_test, random_forest_pred)
print("Accuracy:", accuracy)

precision = precision_score(y_test, random_forest_pred)
print("Precision:", precision)

recall = recall_score(y_test, random_forest_pred)
print("Recall:", recall)

f1 = f1_score(y_test, random_forest_pred)
print("F1 Score:", f1)
# Out:
# Confusion Matrix:
# [[79  9]
#  [21  8]]
# Accuracy: 0.7435897435897436
# Precision: 0.79
# Recall: 0.8977272727272727
# F1 Score: 0.8404255319148937

# %% [markdown]
# ## **Gradient Boosting Classifier**

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

gradient_boosting_model = GradientBoostingClassifier()
gradient_boosting_model.fit(x_train, y_train)

gradient_boosting_pred = gradient_boosting_model.predict(x_test)

conf_matrix = confusion_matrix(y_test, gradient_boosting_pred)
print("Confusion Matrix:")
print(conf_matrix)

accuracy = accuracy_score(y_test, gradient_boosting_pred)
print("Accuracy:", accuracy)

precision = precision_score(y_test, gradient_boosting_pred)
print("Precision:", precision)

recall = recall_score(y_test, gradient_boosting_pred)
print("Recall:", recall)

f1 = f1_score(y_test, gradient_boosting_pred)
print("F1 Score:", f1)
# Out:
# Confusion Matrix:
# [[76 12]
#  [21  8]]
# Accuracy: 0.717948717948718
# Precision: 0.7835051546391752
# Recall: 0.8636363636363636
# F1 Score: 0.8216216216216216

# %% [markdown]
# ## **Decision Tree Classifier**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

decision_tree_model = DecisionTreeClassifier()
decision_tree_model.fit(x_train, y_train)

decision_tree_pred = decision_tree_model.predict(x_test)

conf_matrix = confusion_matrix(y_test, decision_tree_pred)
print("Confusion Matrix:")
print(conf_matrix)

accuracy = accuracy_score(y_test, decision_tree_pred)
print("Accuracy:", accuracy)

precision = precision_score(y_test, decision_tree_pred)
print("Precision:", precision)

recall = recall_score(y_test, decision_tree_pred)
print("Recall:", recall)

f1 = f1_score(y_test, decision_tree_pred)
print("F1 Score:", f1)
# Out:
# Confusion Matrix:
# [[67 21]
#  [17 12]]
# Accuracy: 0.6752136752136753
# Precision: 0.7976190476190477
# Recall: 0.7613636363636364
# F1 Score: 0.7790697674418605

# %% [markdown]
# # **Model Report**

# %% [markdown]
# ### **Here's a ranking of the models from best to worst based on the F1 Score, which is often a good metric for balancing precision and recall:**
#
#
# * **Logistic Regression:**
#
# > Accuracy: 0.7607
#
# > Precision: 0.8000
#
# > Recall: 0.9091
#
# > F1 Score: 0.8511
#
# * **Random Forest Classifier:**
#
# > Accuracy: 0.7436
#
# > Precision: 0.7900
#
# > Recall: 0.8977
#
# > F1 Score: 0.8404
#
# * **Support Vector Classifier (SVC):**
#
# > Accuracy: 0.7521
#
# > Precision: 0.7521
#
# > Recall: 1.0000
#
# > F1 Score: 0.8585
#
# * **Gradient Boosting:**
#
# > Accuracy: 0.7179
#
# > Precision: 0.7835
#
# > Recall: 0.8636
#
# > F1 Score: 0.8216
#
# * **Decision Tree:**
#
# > Accuracy: 0.6752
#
# > Precision: 0.7976
#
# > Recall: 0.7614
#
# > F1 Score: 0.7791
#
#
#
# ### **Logistic Regression is the top choice for liver patient prediction. It strikes a good balance between accurately identifying patients with liver issues (precision) and not wrongly flagging healthy individuals (low false positives). This is crucial for medical diagnosis. It has the highest precision among the models and still maintains a high recall, which means it correctly spots many liver patients while being cautious about false alarms.**
